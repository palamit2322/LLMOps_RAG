# %%
print("Hello world")
# Out:
# Hello world

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

model=ChatOpenAI(model="gpt-4o-mini",temperature=0.5,max_completion_tokens=None,max_retries=2)

response=model.invoke("capital of delhi")
print(response.content)
# Out:
# The capital of Delhi is New Delhi. New Delhi serves as the seat of the government of India and is one of the 11 districts of Delhi. It was officially inaugurated as the capital in 1931.
